# %% [markdown]
# # 📊 Improved 2019 Holdout Model Evaluation Report
#
# **Training Period**: 2014-01-02 to 2018-12-31 (5 full years)
# **Evaluation Holdout**: 2019-01-01 to 2019-10-08 (281 days)
#
# ### Evaluated Metrics (6 Core Demand Metrics):
# 1. **MAE**: Mean Absolute Error
# 2. **MSE**: Mean Squared Error
# 3. **RMSE**: Root Mean Squared Error
# 4. **RMSLE**: Root Mean Squared Logarithmic Error
# 5. **MAPE (%)**: Mean Absolute Percentage Error
# 6. **WAPE (%)**: Weighted Absolute Percentage Error

# %%
import pandas as pd
import os

csv_path = 'model_evaluation_2019_holdout.csv'
df = pd.read_csv(csv_path)

print('========================================================================')
print('  2019 HOLDOUT PERFORMANCE METRICS (OPTIMIZED CHAMPION & ENSEMBLE MODELS)')
print('========================================================================')
display(df.style.highlight_max(subset=['RMSLE', 'MAPE (%)'], color='#f87171')\
                .highlight_min(subset=['RMSLE', 'MAPE (%)'], color='#34d399'))
# Out:
# ========================================================================
#   2019 HOLDOUT PERFORMANCE METRICS (OPTIMIZED CHAMPION & ENSEMBLE MODELS)
# ========================================================================
# <style type="text/css">
# #T_d2228_row1_col5, #T_d2228_row5_col6 {
#   background-color: #34d399;
# }
# #T_d2228_row6_col5, #T_d2228_row6_col6 {
#   background-color: #f87171;
# }
# </style>
# <table id="T_d2228">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2228_level0_col0" class="col_heading level0 col0" >Drug Code</th>
#       <th id="T_d2228_level0_col1" class="col_heading level0 col1" >Best Champion Model</th>
#       <th id="T_d2228_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_d2228_level0_col3" class="col_heading level0 col3" >MSE</th>
#       <th id="T_d2228_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_d2228_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d2228_level0_col6" class="col_heading level0 col6" >MAPE (%)</th>
#       <th id="T_d2228_level0_col7" class="col_heading level0 col7" >WAPE (%)</th>
#       <th id="T_d2228_level0_col8" class="col_heading level0 col8" >Evaluation Days</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2228_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2228_row0_col0" class="data row0 col0" >M01AB</td>
#       <td id="T_d2228_row0_col1" class="data row0 col1" >LightGBM + XGBoost Ensemble</td>
#       <td id="T_d2228_row0_col2" class="data row0 col2" >2.259000</td>
#       <td id="T_d2228_row0_col3" class="data row0 col3" >8.377000</td>
#       <td id="T_d2228_row0_col4" class="data row0 col4" >2.894000</td>
#       <td id="T_d2228_row0_col5" class="data row0 col5" >0.519200</td>
#       <td id="T_d2228_row0_col6" class="data row0 col6" >66.480000</td>
#       <td id="T_d2228_row0_col7" class="data row0 col7" >41.830000</td>
#       <td id="T_d2228_row0_col8" class="data row0 col8" >281</td>
#     </tr>
#     <tr>
#       <th id="T_d2228_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2228_row1_col0" class="data row1 col0" >M01AE</td>
#       <td id="T_d2228_row1_col1" class="data row1 col1" >CatBoost Regressor (RMSE Loss)</td>
#       <td id="T_d2228_row1_col2" class="data row1 col2" >1.675000</td>
#       <td id="T_d2228_row1_col3" class="data row1 col3" >4.851000</td>
#       <td id="T_d2228_row1_col4" class="data row1 col4" >2.202000</td>
#       <td id="T_d2228_row1_col5" class="data row1 col5" >0.506100</td>
#       <td id="T_d2228_row1_col6" class="data row1 col6" >70.240000</td>
#       <td id="T_d2228_row1_col7" class="data row1 col7" >43.400000</td>
#       <td id="T_d2228_row1_col8" class="data row1 col8" >281</td>
#     </tr>
#     <tr>
#       <th id="T_d2228_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2228_row2_col0" class="data row2 col0" >N02BA</td>
#       <td id="T_d2228_row2_col1" class="data row2 col1" >CatBoost Regressor</td>
#       <td id="T_d2228_row2_col2" class="data row2 col2" >1.522000</td>
#       <td id="T_d2228_row2_col3" class="data row2 col3" >3.747000</td>
#       <td id="T_d2228_row2_col4" class="data row2 col4" >1.936000</td>
#       <td id="T_d2228_row2_col5" class="data row2 col5" >0.536700</td>
#       <td id="T_d2228_row2_col6" class="data row2 col6" >76.260000</td>
#       <td id="T_d2228_row2_col7" class="data row2 col7" >48.610000</td>
#       <td id="T_d2228_row2_col8" class="data row2 col8" >281</td>
#     </tr>
#     <tr>
#       <th id="T_d2228_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2228_row3_col0" class="data row3 col0" >N02BE</td>
#       <td id="T_d2228_row3_col1" class="data row3 col1" >Stacking Regressor (Ridge/Huber Meta-Learner)</td>
#       <td id="T_d2228_row3_col2" class="data row3 col2" >8.416000</td>
#       <td id="T_d2228_row3_col3" class="data row3 col3" >127.675000</td>
#       <td id="T_d2228_row3_col4" class="data row3 col4" >11.299000</td>
#       <td id="T_d2228_row3_col5" class="data row3 col5" >0.527600</td>
#       <td id="T_d2228_row3_col6" class="data row3 col6" >69.690000</td>
#       <td id="T_d2228_row3_col7" class="data row3 col7" >29.630000</td>
#       <td id="T_d2228_row3_col8" class="data row3 col8" >281</td>
#     </tr>
#     <tr>
#       <th id="T_d2228_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2228_row4_col0" class="data row4 col0" >N05B</td>
#       <td id="T_d2228_row4_col1" class="data row4 col1" >LightGBM + XGBoost Ensemble</td>
#       <td id="T_d2228_row4_col2" class="data row4 col2" >3.184000</td>
#       <td id="T_d2228_row4_col3" class="data row4 col3" >17.117000</td>
#       <td id="T_d2228_row4_col4" class="data row4 col4" >4.137000</td>
#       <td id="T_d2228_row4_col5" class="data row4 col5" >0.536800</td>
#       <td id="T_d2228_row4_col6" class="data row4 col6" >69.470000</td>
#       <td id="T_d2228_row4_col7" class="data row4 col7" >37.190000</td>
#       <td id="T_d2228_row4_col8" class="data row4 col8" >281</td>
#     </tr>
#     <tr>
#       <th id="T_d2228_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2228_row5_col0" class="data row5 col0" >N05C</td>
#       <td id="T_d2228_row5_col1" class="data row5 col1" >ARIMA + LightGBM Blend</td>
#       <td id="T_d2228_row5_col2" class="data row5 col2" >0.829000</td>
#       <td id="T_d2228_row5_col3" class="data row5 col3" >1.220000</td>
#       <td id="T_d2228_row5_col4" class="data row5 col4" >1.105000</td>
#       <td id="T_d2228_row5_col5" class="data row5 col5" >0.524500</td>
#       <td id="T_d2228_row5_col6" class="data row5 col6" >57.630000</td>
#       <td id="T_d2228_row5_col7" class="data row5 col7" >118.880000</td>
#       <td id="T_d2228_row5_col8" class="data row5 col8" >281</td>
#     </tr>
#     <tr>
#       <th id="T_d2228_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d2228_row6_col0" class="data row6 col0" >R03</td>
#       <td id="T_d2228_row6_col1" class="data row6 col1" >XGBoost + LightGBM Quantile</td>
#       <td id="T_d2228_row6_col2" class="data row6 col2" >5.344000</td>
#       <td id="T_d2228_row6_col3" class="data row6 col3" >60.692000</td>
#       <td id="T_d2228_row6_col4" class="data row6 col4" >7.791000</td>
#       <td id="T_d2228_row6_col5" class="data row6 col5" >1.020500</td>
#       <td id="T_d2228_row6_col6" class="data row6 col6" >183.120000</td>
#       <td id="T_d2228_row6_col7" class="data row6 col7" >77.140000</td>
#       <td id="T_d2228_row6_col8" class="data row6 col8" >281</td>
#     </tr>
#     <tr>
#       <th id="T_d2228_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d2228_row7_col0" class="data row7 col0" >R06</td>
#       <td id="T_d2228_row7_col1" class="data row7 col1" >LightGBM + SHAP Ensemble</td>
#       <td id="T_d2228_row7_col2" class="data row7 col2" >1.721000</td>
#       <td id="T_d2228_row7_col3" class="data row7 col3" >5.329000</td>
#       <td id="T_d2228_row7_col4" class="data row7 col4" >2.308000</td>
#       <td id="T_d2228_row7_col5" class="data row7 col5" >0.529400</td>
#       <td id="T_d2228_row7_col6" class="data row7 col6" >66.040000</td>
#       <td id="T_d2228_row7_col7" class="data row7 col7" >45.040000</td>
#       <td id="T_d2228_row7_col8" class="data row7 col8" >281</td>
#     </tr>
#     <tr>
#       <th id="T_d2228_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d2228_row8_col0" class="data row8 col0" >PORTFOLIO AVG</td>
#       <td id="T_d2228_row8_col1" class="data row8 col1" >Optimal Champion Pipeline</td>
#       <td id="T_d2228_row8_col2" class="data row8 col2" >3.119000</td>
#       <td id="T_d2228_row8_col3" class="data row8 col3" >28.626000</td>
#       <td id="T_d2228_row8_col4" class="data row8 col4" >4.209000</td>
#       <td id="T_d2228_row8_col5" class="data row8 col5" >0.587600</td>
#       <td id="T_d2228_row8_col6" class="data row8 col6" >82.370000</td>
#       <td id="T_d2228_row8_col7" class="data row8 col7" >55.220000</td>
#       <td id="T_d2228_row8_col8" class="data row8 col8" >281</td>
#     </tr>
#   </tbody>
# </table>
